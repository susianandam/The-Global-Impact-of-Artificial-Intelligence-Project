# %%
import pandas as pd
df=pd.read_csv("C:/Personal/Susi/Barcelona_Activa/Project/Cleaned Dataset/ai_index_gdp.csv")

# %%
df1=df.copy()

# %%
df1
# Out:
#                      Country  Talent  Infrastructure  Operating Environment  \
# 0   United States of America  100.00           94.02                  64.56
# 1                      China   16.51          100.00                  91.57
# 2             United Kingdom   39.65           71.43                  74.65
# 3                     Canada   31.28           77.05                  93.94
# 4                     Israel   35.76           67.58                  82.44
# 5                  Singapore   39.38           84.30                  43.15
# 6            The Netherlands   33.83           81.99                  88.05
# 7                    Germany   27.63           77.22                  70.22
# 8                     France   28.32           77.15                  80.02
# 9                  Australia   25.43           63.43                  61.23
# 10                   Ireland   29.93           89.50                  70.15
# ...

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
df1['Country'].unique()
# Out:
# array(['United States of America', 'China', 'United Kingdom', 'Canada',
#        'Israel', 'Singapore', 'The Netherlands', 'Germany', 'France',
#        'Australia', 'Ireland', 'Finland', 'Denmark', 'Luxembourg',
#        'Japan', 'India', 'Switzerland', 'Sweden', 'Hong Kong', 'Spain',
#        'Austria', 'Estonia', 'Norway', 'Saudi Arabia', 'Belgium',
#        'Poland', 'Slovenia', 'New Zealand', 'Italy', 'Russia', 'Malta',
#        'United Arab Emirates', 'Portugal', 'Czech Republic', 'Iceland',
#        'Lithuania', 'Brazil', 'Greece', 'Slovakia', 'Hungary', 'Malaysia',
#        'Mexico', 'Chile', 'Argentina', 'Qatar', 'Turkey', 'Colombia',
#        'Uruguay', 'Bahrain', 'Vietnam', 'Indonesia', 'Tunisia',
#        'South Africa', 'Morocco', 'Armenia', 'Sri Lanka', 'Egypt',
#        'Kenya', 'Nigeria', 'Pakistan'], dtype=object)

# %%
import pandas as pd
df2 = pd.read_csv("C:/Personal/Susi/Barcelona_Activa/Project/Dataset/R&D_dataset.csv",skiprows=2)

# %%
df2
# Out:
#           Category  % of GDP
# 0           Israel  6.345883
# 1            Korea  4.958960
# 2           Sweden  3.640187
# 3    United States  3.447163
# 4            Japan  3.441249
# 5          Belgium  3.272349
# 6          Austria  3.255170
# 7      Switzerland  3.221781
# 8          Germany  3.128664
# 9          Finland  3.093055
# 10         Denmark  3.066791
# 11  United Kingdom  2.676140
# 12         Iceland  2.620065
# 13     Netherlands  2.304896
# 14          France  2.175166
# 15        Slovenia  2.130563
# 16          Norway  1.851424
# 17         Estonia  1.830836
# 18         Czechia  1.823842
# 19          Canada  1.810479
# 20        Portugal  1.694905
# 21          Poland  1.555247
# 22     New Zealand  1.548483
# 23         Ireland  1.543566
# 24          Greece  1.494301
# 25           Spain  1.493612
# 26         Türkiye  1.422234
# 27         Hungary  1.377477
# 28           Italy  1.372136
# 29      Luxembourg  1.055807
# 30       Lithuania  1.049770
# ...

# %%
df3=df2.copy()

# %%
df3.rename(columns={"Category": "Country"}, inplace=True)

# %%
df3["Country"].unique()
# Out:
# array(['Israel', 'Korea', 'Sweden', 'United States', 'Japan', 'Belgium',
#        'Austria', 'Switzerland', 'Germany', 'Finland', 'Denmark',
#        'United Kingdom', 'Iceland', 'Netherlands', 'France', 'Slovenia',
#        'Norway', 'Estonia', 'Czechia', 'Canada', 'Portugal', 'Poland',
#        'New Zealand', 'Ireland', 'Greece', 'Spain', 'Türkiye', 'Hungary',
#        'Italy', 'Luxembourg', 'Lithuania', 'Slovak Rep.', 'Latvia'],
#       dtype=object)

# %%
df3.isnull().sum().sum()
# Out:
# 0

# %%
country_mapping = {
    "United States": "United States of America",
    "Netherlands": "The Netherlands",
    "Czechia": "Czech Republic",
    "Türkiye": "Turkey",
    "Slovak Rep.": "Slovakia"
}

# %%
df3['Country']=df3['Country'].replace(country_mapping)

# %%
merged_df1 = pd.merge(
    df3,
    df1,
    on=['Country'],
    how='inner'
)

# %%
merged_df1
# Out:
#                      Country  % of GDP  Talent  Infrastructure  \
# 0                     Israel  6.345883   35.76           67.58
# 1                     Sweden  3.640187   28.21           75.19
# 2   United States of America  3.447163  100.00           94.02
# 3                      Japan  3.441249   15.18           84.58
# 4                    Belgium  3.272349   15.17           65.10
# 5                    Austria  3.255170   16.97           64.49
# 6                Switzerland  3.221781   25.63           78.43
# 7                    Germany  3.128664   27.63           77.22
# 8                    Finland  3.093055   24.99           71.60
# 9                    Denmark  3.066791   27.07           74.08
# 10            United Kingdom  2.676140   39.65           71.43
# 11                   Iceland  2.620065   18.45           72.45
# 12           The Netherlands  2.304896   33.83           81.99
# 13                    France  2.175166   28.32           77.15
# ...

# %%
merged_df1.isnull().sum().sum()
# Out:
# 0

# %%
merged_df1.to_csv(r"C:/Personal/Susi/Barcelona_Activa/Project/Cleaned Dataset/ai_adopt_R&D.csv",index=False)
