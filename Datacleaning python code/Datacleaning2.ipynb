# %%
import pandas as pd
df = pd.read_csv("C:/Personal/Susi/Barcelona_Activa/Project/Dataset/AI_index_db.csv")

# %%
df1= df.copy()

# %%
df1
# Out:
#                      Country  Talent  ...  Income group     Political regime
# 0   United States of America  100.00  ...          High    Liberal democracy
# 1                      China   16.51  ...  Upper middle     Closed autocracy
# 2             United Kingdom   39.65  ...          High    Liberal democracy
# 3                     Canada   31.28  ...          High    Liberal democracy
# 4                     Israel   35.76  ...          High    Liberal democracy
# ..                       ...     ...  ...           ...                  ...
# 57                 Sri Lanka    6.27  ...  Lower middle  Electoral democracy
# 58                     Egypt    1.11  ...  Lower middle  Electoral autocracy
# 59                     Kenya    0.75  ...  Lower middle  Electoral autocracy
# 60                   Nigeria    2.74  ...  Lower middle  Electoral autocracy
# 61                  Pakistan    8.00  ...  Lower middle  Electoral autocracy
#
# [62 rows x 13 columns]

# %%
df1.head(60)
# Out:
#                      Country  Talent  ...  Income group     Political regime
# 0   United States of America  100.00  ...          High    Liberal democracy
# 1                      China   16.51  ...  Upper middle     Closed autocracy
# 2             United Kingdom   39.65  ...          High    Liberal democracy
# 3                     Canada   31.28  ...          High    Liberal democracy
# 4                     Israel   35.76  ...          High    Liberal democracy
# 5                  Singapore   39.38  ...          High  Electoral democracy
# 6                South Korea   14.54  ...          High    Liberal democracy
# 7            The Netherlands   33.83  ...          High    Liberal democracy
# 8                    Germany   27.63  ...          High    Liberal democracy
# 9                     France   28.32  ...          High    Liberal democracy
# 10                 Australia   25.43  ...          High    Liberal democracy
# ...

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                62 non-null     object
#  1   Talent                 62 non-null     float64
#  2   Infrastructure         62 non-null     float64
#  3   Operating Environment  62 non-null     float64
#  4   Research               62 non-null     float64
#  5   Development            62 non-null     float64
#  6   Government Strategy    62 non-null     float64
#  7   Commercial             62 non-null     float64
#  8   Total score            62 non-null     float64
#  9   Region                 62 non-null     object
#  10  Cluster                62 non-null     object
#  11  Income group           62 non-null     object
#  12  Political regime       62 non-null     object
# dtypes: float64(8), object(5)
# memory usage: 6.4+ KB

# %%
df1['Country'].unique()
# Out:
# array(['United States of America', 'China', 'United Kingdom', 'Canada',
#        'Israel', 'Singapore', 'South Korea', 'The Netherlands', 'Germany',
#        'France', 'Australia', 'Ireland', 'Finland', 'Denmark',
#        'Luxembourg', 'Japan', 'India', 'Switzerland', 'Sweden',
#        'Hong Kong', 'Spain', 'Austria', 'Estonia', 'Taiwan', 'Norway',
#        'Saudi Arabia', 'Belgium', 'Poland', 'Slovenia', 'New Zealand',
#        'Italy', 'Russia', 'Malta', 'United Arab Emirates', 'Portugal',
#        'Czech Republic', 'Iceland', 'Lithuania', 'Brazil', 'Greece',
#        'Slovakia', 'Hungary', 'Malaysia', 'Mexico', 'Chile', 'Argentina',
#        'Qatar', 'Turkey', 'Colombia', 'Uruguay', 'Bahrain', 'Vietnam',
#        'Indonesia', 'Tunisia', 'South Africa', 'Morocco', 'Armenia',
#        'Sri Lanka', 'Egypt', 'Kenya', 'Nigeria', 'Pakistan'], dtype=object)

# %%
import pandas as pd
df2 = pd.read_csv("C:/Personal/Susi/Barcelona_Activa/Project/Dataset/GDP_country.csv",skiprows=4)

# %%
df3= df2.copy()

# %%
df3['Country Name'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %%
country_mapping = {
 'United States':'United States of America',
    'China': 'China', 
   'United Kingdom': 'United Kingdom',
  'Canada'  :'Canada',
   'Israel'    :'Israel', 
    'Singapore':'Singapore',
   'Korea, Rep.' :'South Korea', 
   'Netherlands' :'The Netherlands',
    'Germany':'Germany',
    'France'   :'France', 
    'Australia':'Australia', 
   'Ireland' :'Ireland', 
  'Finland'  :'Finland', 
    'Denmark':'Denmark',
       'Luxembourg':'Luxembourg', 
    'Japan':'Japan', 
    'India':'India', 
    'Switzerland':'Switzerland',
   'Sweden':'Sweden',
       'Hong Kong SAR, China':'Hong Kong', 
    'Spain':'Spain',
    'Austria':'Austria', 
    'Estonia':'Estonia',
        'Norway':'Norway',
       'Saudi Arabia':'Saudi Arabia', 
    'Belgium':'Belgium', 
    'Poland':'Poland', 
    'Slovenia':'Slovenia', 
    'New Zealand':'New Zealand',
       'Italy':'Italy',
    'Russian Federation':'Russia',
    'Malta':'Malta', 
    'United Arab Emirates':'United Arab Emirates',
    'Portugal':'Portugal',
       'Czechia':'Czech Republic', 
    'Iceland':'Iceland',
    'Lithuania':'Lithuania', 
    'Brazil':'Brazil', 
    'Greece':'Greece',
      'Slovak Republic' :'Slovakia', 
    'Hungary':'Hungary', 
    'Malaysia':'Malaysia',
    'Mexico':'Mexico', 
    'Chile':'Chile', 
    'Argentina':'Argentina',
       'Qatar':'Qatar', 
    'Turkiye':'Turkey', 
    'Colombia':'Colombia',
    'Uruguay':'Uruguay',
    'Bahrain':'Bahrain',
    'Viet Nam':'Vietnam',
     'Indonesia'  :'Indonesia',
    'Tunisia':'Tunisia', 
    'South Africa':'South Africa', 
    'Morocco':'Morocco',
    'Armenia':'Armenia',
    'Sri Lanka'   :'Sri Lanka', 
    'Egypt, Arab Rep.':'Egypt',
    'Kenya':'Kenya',
    'Nigeria':'Nigeria', 
    'Pakistan':'Pakistan'}

# %%
df3['Country Name']=df3['Country Name'].replace(country_mapping)

# %%
df3['Country Name'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica',
# ...

# %%
selected_df3 = df3[['Country Name','2023','2024']]

# %%
selected_df3
# Out:
#                     Country Name          2023          2024
# 0                          Aruba  3.648573e+09           NaN
# 1    Africa Eastern and Southern  1.133818e+12  1.205974e+12
# 2                    Afghanistan  1.715223e+10           NaN
# 3     Africa Western and Central  8.147285e+11  6.700257e+11
# 4                         Angola  8.487516e+10  8.039694e+10
# ..                           ...           ...           ...
# 261                       Kosovo  1.046822e+10  1.114860e+10
# 262                  Yemen, Rep.           NaN           NaN
# 263                 South Africa  3.806993e+11  4.002607e+11
# 264                       Zambia  2.757796e+10  2.632578e+10
# 265                     Zimbabwe  3.523137e+10  4.418770e+10
#
# [266 rows x 3 columns]

# %%
selected_df3 = selected_df3.rename(columns={'Country Name':'Country'})

# %%
selected_df3
# Out:
#                          Country          2023          2024
# 0                          Aruba  3.648573e+09           NaN
# 1    Africa Eastern and Southern  1.133818e+12  1.205974e+12
# 2                    Afghanistan  1.715223e+10           NaN
# 3     Africa Western and Central  8.147285e+11  6.700257e+11
# 4                         Angola  8.487516e+10  8.039694e+10
# ..                           ...           ...           ...
# 261                       Kosovo  1.046822e+10  1.114860e+10
# 262                  Yemen, Rep.           NaN           NaN
# 263                 South Africa  3.806993e+11  4.002607e+11
# 264                       Zambia  2.757796e+10  2.632578e+10
# 265                     Zimbabwe  3.523137e+10  4.418770e+10
#
# [266 rows x 3 columns]

# %%
selected_df3.isnull().sum().sum()
# Out:
# 53

# %%
import pandas as pd

df_joined = df1.merge(selected_df3, on="Country")

# %%
df_joined
# Out:
#                      Country  Talent  ...          2023          2024
# 0   United States of America  100.00  ...  2.772071e+13  2.918489e+13
# 1                      China   16.51  ...  1.827036e+13  1.874380e+13
# 2             United Kingdom   39.65  ...  3.369862e+12  3.643834e+12
# 3                     Canada   31.28  ...  2.173340e+12  2.241253e+12
# 4                     Israel   35.76  ...  5.121846e+11  5.403799e+11
# ..                       ...     ...  ...           ...           ...
# 56                 Sri Lanka    6.27  ...  8.371614e+10  9.896319e+10
# 57                     Egypt    1.11  ...  3.959261e+11  3.890599e+11
# 58                     Kenya    0.75  ...  1.080386e+11  1.244987e+11
# 59                   Nigeria    2.74  ...  3.638463e+11  1.877597e+11
# 60                  Pakistan    8.00  ...  3.378855e+11  3.730719e+11
#
# [61 rows x 15 columns]

# %%
df_joined.isnull().sum().sum()
# Out:
# 1

# %%
df_joined[df_joined.isnull().any(axis=1)]
# Out:
#        Country  Talent  Infrastructure  ...   Political regime          2023  2024
# 6  South Korea   14.54           85.23  ...  Liberal democracy  1.712793e+12   NaN
#
# [1 rows x 15 columns]

# %%
df_joined.isnull().sum()
# Out:
# Country                  0
# Talent                   0
# Infrastructure           0
# Operating Environment    0
# Research                 0
# Development              0
# Government Strategy      0
# Commercial               0
# Total score              0
# Region                   0
# Cluster                  0
# Income group             0
# Political regime         0
# 2023                     0
# 2024                     1
# dtype: int64

# %%
df_joined.dropna(inplace=True)

# %%
df_joined.isnull().sum()
# Out:
# Country                  0
# Talent                   0
# Infrastructure           0
# Operating Environment    0
# Research                 0
# Development              0
# Government Strategy      0
# Commercial               0
# Total score              0
# Region                   0
# Cluster                  0
# Income group             0
# Political regime         0
# 2023                     0
# 2024                     0
# dtype: int64

# %%
df_joined.isnull().sum().sum()
# Out:
# 0

# %%
df_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 0 to 60
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                60 non-null     object
#  1   Talent                 60 non-null     float64
#  2   Infrastructure         60 non-null     float64
#  3   Operating Environment  60 non-null     float64
#  4   Research               60 non-null     float64
#  5   Development            60 non-null     float64
#  6   Government Strategy    60 non-null     float64
#  7   Commercial             60 non-null     float64
#  8   Total score            60 non-null     float64
#  9   Region                 60 non-null     object
#  10  Cluster                60 non-null     object
#  11  Income group           60 non-null     object
#  12  Political regime       60 non-null     object
#  13  2023                   60 non-null     float64
# ...

# %%
df_joined.head(60)
# Out:
#                      Country  Talent  ...          2023          2024
# 0   United States of America  100.00  ...  2.772071e+13  2.918489e+13
# 1                      China   16.51  ...  1.827036e+13  1.874380e+13
# 2             United Kingdom   39.65  ...  3.369862e+12  3.643834e+12
# 3                     Canada   31.28  ...  2.173340e+12  2.241253e+12
# 4                     Israel   35.76  ...  5.121846e+11  5.403799e+11
# 5                  Singapore   39.38  ...  5.054395e+11  5.473866e+11
# 7            The Netherlands   33.83  ...  1.154361e+12  1.227544e+12
# 8                    Germany   27.63  ...  4.525704e+12  4.659929e+12
# 9                     France   28.32  ...  3.051832e+12  3.162079e+12
# 10                 Australia   25.43  ...  1.728057e+12  1.752193e+12
# 11                   Ireland   29.93  ...  5.513949e+11  5.773895e+11
# 12                   Finland   24.99  ...  2.949506e+11  2.998356e+11
# ...

# %%
df_index_gdp = df_joined.copy()

# %%
df_index_gdp.to_csv(r"C:/Personal/Susi/Barcelona_Activa/Project/Cleaned Dataset/ai_index_gdp.csv",index=False)
